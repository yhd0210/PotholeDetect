# %%
import os
import numpy as np
import albumentations as A
import cv2
import torch as T
from torch.utils.data import Dataset
from PIL import Image
from tqdm import tqdm
# Out:
# c:\ProgramData\anaconda3\envs\ia\lib\site-packages\scipy\__init__.py:169: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.13 (you have 1.4.12). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.

# %%
albumentations_transform =  A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.Blur(p=0.5),
    A.OpticalDistortion(p=0.2),
    A.GaussNoise(var_limit=(10.0, 50.0), p=0.2),
    A.ShiftScaleRotate(rotate_limit=2.5, p=0.5,),
], bbox_params=A.BboxParams(format='yolo', label_fields=['category_ids']))

# %%
class CustomDataset(Dataset):
    def __init__(self, image_folder, label_folder, transform=None):
        self.image_folder = image_folder
        self.label_folder = label_folder
        self.image_names = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
        self.transform = transform

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):
        img_name = self.image_names[idx]
        img_path = os.path.join(self.image_folder, img_name)
        label_path = os.path.join(self.label_folder, img_name.replace('.jpg', '.txt'))

        image = np.array(Image.open(img_path).convert("RGB"))

        with open(label_path, 'r') as file:
            bboxes = []
            category_ids = []
            for line in file:
                parts = line.strip().split()
                category_ids.append(int(parts[0]))
                bboxes.append([float(parts[1]), float(parts[2]), float(parts[3]), float(parts[4])])

        if self.transform:
            augmented = self.transform(image=image, bboxes=bboxes, category_ids=category_ids)
            image = augmented['image']
            bboxes = augmented['bboxes']
            category_ids = augmented['category_ids']
        
        image = T.from_numpy(image.transpose((2, 0, 1))).float() / 255.0
        return image, bboxes, category_ids, img_name

image_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/pothole_data/images"
label_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/pothole_data/labels"
dataset = CustomDataset(image_folder, label_folder, transform=albumentations_transform)

# %%
def save_augmented_data(dataset, output_image_folder, output_label_folder, num_augmentations=20):
    if not os.path.exists(output_image_folder):
        os.makedirs(output_image_folder)
    if not os.path.exists(output_label_folder):
        os.makedirs(output_label_folder)
    
    for i in tqdm(range(len(dataset))):
        image, bboxes, category_ids, img_name = dataset[i]
        image = image.numpy().transpose((1, 2, 0)) * 255
        image = image.astype(np.uint8)

        for j in range(num_augmentations):
            augmented = dataset.transform(image=image, bboxes=bboxes, category_ids=category_ids)
            aug_image = augmented['image']
            aug_bboxes = augmented['bboxes']
            aug_category_ids = augmented['category_ids']
            
            aug_image_name = f"{img_name.replace('.jpg', '')}_aug_{j}.jpg"
            aug_image_path = os.path.join(output_image_folder, aug_image_name)
            cv2.imwrite(aug_image_path, cv2.cvtColor(aug_image, cv2.COLOR_RGB2BGR))

            aug_label_path = os.path.join(output_label_folder, f"{img_name.replace('.jpg', '')}_aug_{j}.txt")
            with open(aug_label_path, 'w') as file:
                for bbox, category_id in zip(aug_bboxes, aug_category_ids):
                    file.write(f"{category_id} {' '.join(map(str, bbox))}\n")

output_image_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_potehole_dataset/images"
output_label_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_potehole_dataset/labels"
save_augmented_data(dataset, output_image_folder, output_label_folder, num_augmentations=20)
# Out:
# 100%|██████████| 313/313 [11:42<00:00,  2.25s/it]

# %%
image_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_potehole_dataset/images"
label_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_potehole_dataset/labels"
# image_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_potehole_dataset/images"
# label_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_potehole_dataset/labels"
output_image_folder = "C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images"

def draw_bbox(image_path, label_path, output_image_folder):
    image = cv2.imread(image_path)
    if image is None:
        print(f"이미지를 불러오는 것을 실패하였습니다: {image_path}")
        return
    height, width, _ = image.shape

    with open(label_path, 'r') as f:
        labels = f.readlines()

    for label in labels:
        class_id, x_center, y_center, bbox_width, bbox_height = map(float, label.split())

        x_center = int(x_center * width)
        y_center = int(y_center * height)
        bbox_width = int(bbox_width * width)
        bbox_height = int(bbox_height * height)

        x1 = int(x_center - bbox_width / 2)
        y1 = int(y_center - bbox_height / 2)
        x2 = int(x_center + bbox_width / 2)
        y2 = int(y_center + bbox_height / 2)

        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

    os.makedirs(output_image_folder, exist_ok=True)

    output_image_path = os.path.join(output_image_folder, os.path.basename(image_path))

    cv2.imwrite(output_image_path, image)
    print(f"바운딩 박스가 있는 저장된 이미지: {output_image_path}")

for image_filename in os.listdir(image_folder):
    image_path = os.path.join(image_folder, image_filename)
    label_path = os.path.join(label_folder, os.path.splitext(image_filename)[0] + '.txt')

    if os.path.exists(label_path):
        draw_bbox(image_path, label_path, output_image_folder)
    else:
        print(f"해당 이미지의 라벨 파일을 찾을 수 없음: {image_filename}")
# Out:
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0007648_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0011245_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0013624_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014324_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014434_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0014439_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017212_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0017554_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0019809_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0020233_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0021014_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0023685_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024132_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0024133_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0026318_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0028826_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0031520_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0034065_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039349_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0039775_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0041272_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043322_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0043979_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\0051194_aug_15.jpg
# ...
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_1_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_1_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_1_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_2_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_86_3_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_1_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_2_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_87_3_aug_9.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_0.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_1.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_10.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_11.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_12.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_13.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_14.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_15.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_16.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_17.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_18.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_19.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_2.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_3.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_4.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_5.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_6.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_7.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_8.jpg
# 바운딩 박스가 있는 저장된 이미지: C:/Users/yhd06/OneDrive/Desktop/iwaz/pothole_data/output_images\PM_sunny_CI03_20211007_143835_88_1_aug_9.jpg
